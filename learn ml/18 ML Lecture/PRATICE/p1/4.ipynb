# %%
# PASS BY REFRANCE

# %%
class Person:
    def __init__(self, name , gender):
        self.name = name 
        self.gender = gender

Person('Satyam', 'yadav')

x = Person('puru','singh')

y = x

print(y.gender)
# Out:
# singh
