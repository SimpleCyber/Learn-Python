# %%
# today goals 

# revison

# %% [markdown]
# # OOPs => we can create an out data types
#
# # write oop classes to handle the followin scenarios
#
# # a user can sreaye and viev 2D coordinates
# # a user can find the distance of a coordinate from origin
# # a user can check a point lies on agivem=n line or not
#
# # a user can find the distance between a given 2d point and a given line

# %%
class Point:
    def __init__(self,x,y):
        self.x_cord = x
        self.y_cord = y

    def __str__(self):
        # we can print oyr data type in our way
        return '<{},{}>'.format(self.x_cord , self.y_cord)
    
    def euclidean_distance(self , other):
        # self is first point  x1, y1
        # other is second pint x2, y2
        # distance formula  square_root((x2-x1)pow2 +(y2-y1)pow2)
        return ((self.x_cord - other.x_cord)**2  +  (self.y_cord - other.y_cord)**2)**0.5
    
    def distance_from_origin(self):
        return self.euclidean_distance(Point(0,0))




class line:
    def __init__(self, A, B,C):
        self.A = A
        self.B = B
        self.C = C

    def __str__(self):
        return '{}x +{}y +{} = 0 '.format(self.A ,self.B ,self.C )
    
    # how to check point lies on a line or not
    # point ka x, y lo aur , line ke x, y mai dal do lhs=rhs exist

    def point_on_line(line , point):
        if ((line.A * point.x_cord) +(line.B * point.y_cord )+ line.C) ==0:
            return "lies on the line"
        else:
            return "does not exist"

    def sohortest_path(line ,point):
        return abs(line.A * point.x_cord   +    line.B * point.y_cord   +   line.C )/( line.A**2 + line.B**2)**0.5
    

    def intersection_of_2lines(line ,other):
        if line.A * other.B - line.B * other.A != 0:
            return ("the lines intersect at a single point.")
        elif (line.A * other.B - line.B * other.A == 0) and (line.C * other.B - line.B * other.C == 0):
            return "the lines are coincident (they overlap)."
        elif (line.A * other.B - line.B * other.A == 0) and (line.C * other.B - line.B * other.C != 0):
            return "the lines are parallel and do not intersect."

# %%
l1 = line(1,1,-2)
print(l1)


p1 = Point(1,9)
print(p1)

# que 4
l1.point_on_line(p1)

# que 5
l1.sohortest_path(p1)


l2 = line(1,6,6)
l1.intersection_of_2lines(l2)
# Out:
# 1x +1y +-2 = 0
# <1,9>
# 'the lines intersect at a single point.'

# %%
p1 = Point(0 ,4)
# <x,y>
print(p1)

p2 = Point(10,10)
print(p2)


p1.euclidean_distance(p2)
# every thing is same p1 from satrt, 
# p2 we need to pass it differently

print("distance_from_origin :",p2.distance_from_origin())
# Out:
# <0,4>
# <10,10>
# distance_from_origin : 14.142135623730951

# %%
# pass by Refrance

# %%
class Person:
    def __init__(self,name , gender):
        self.name  = name 
        self.gender = gender
    
#  out side the class 
        
Person("satya", "singh")
# this will craete the object ,  us it will be lost 
# in the memory hence we give yhe refrance to the other 
# varisbale so i can use it latter 

x= Person("satyam", "yadav")
# here x is just a refrance , it jyst stores te reftranceof a object

y = x
# copy the data , 2 var  , points on the same object

# %%
# pass the refrance

class Person:
    def __init__(self,name , gender):
        self.name  = name 
        self.gender = gender

#  out side the class 


def greet(person):
    print('hii my name is',person.name,'and i am is a ',person.gender)
    p1 = Person("ankit","male")
    # function ko object bhe input de sakte ho and  viceversa
    return p1
    # function return back the object


x = Person("satya", "singh")
# function ko class ka object input
p2 = greet(x)

print(p2.name , p2.gender)
# Out:
# hii my name is satya and i am is a  singh
# ankit male

# %%
# pass the refrance

class Person:
    def __init__(self,name , gender):
        self.name  = name 
        self.gender = gender

def greet(person):
    print(id(person))
    print('hii my name is',person.name,'and i am is a ',person.gender)


x = Person("satya", "singh")
p2 = greet(x)
print(id(x))

# all objects in classes in userdefine is mutable just line list , dictionaries

# reason  no change in address it change on place (in memeory changes)
# Out:
# 2250941933856
# hii my name is satya and i am is a  singh
# 2250941933856

# %%
# Encapsulation => 

# instance variable => eak aisa variable jiska value alag alag objets ke liye value different hoti hai 

# clwear example  => 2 objects of same class , having vaiable (a) in constructor , but value of (a) for 2 differnt objects will be different 

# examples  : variable in constructor => instance variable

# %%
# story time => u are a senior programer atm senior and junior developor


class Atm:

    # constructor
    # all variables will be streated inside the constructor
    # self. is necessary
    def __init__(self):

        self.pin = ''
        self.__balance = 0
        print("self address :",id(self))
        # self.menu()

    def get_balance(self):
        return self.__balance
    
    def set_balance(self, num):
        if(type(num)== int):
            self.__balance = num
        else:
            print('Beta bouhat mare ge')


    def menu(self):
        user_input = input("""
        Hi how i can help u ?\n
        1. Press 1 to create pin\n
        2. Press 2 to change pin\n
        3. Press 3 to check balance\n
        4. Press 4 to  withdraw\n
        5. Press anythig else to exit\n
        """)

        if user_input == '1':
            self.create_pin()

        elif user_input == '2':
            self.change_pin()

        elif user_input == '3':
            self.check_balance()

        elif user_input == '4':
            self.withdraw_amt()
            pass
        else :
            exit()

    def create_pin(self):
        user_pin = input('enter your pin :' )
        self.pin = user_pin

        user_balance = int(input("Enter Balance :"))
        self.__balance = user_balance

        print("PIN  created sucessfully")
        self.menu()


    def change_pin(self):
        old_pin = input('enter your old pin :' )
        if old_pin == self.pin :
            user_pin = input('enter your New pin :' )
            self.pin = user_pin
            print("PIN  updated sucessfully")
            self.menu()

        else :
            print("Invalid pin :)")
            self.menu()

    def check_balance(self):
        user_pin = input('enter your  pin :' )
        if user_pin == self.pin :
            print("amount in your balance ", self.__balance)
            self.menu()
        else:
            print("Chal nikal isha se")
            self.menu()

    def withdraw_amt(self):
        user_pin = input('enter your  pin :' )
        if user_pin == self.pin :
            amt_withdraw = int(input("Enter amount to withdraw"))

            if amt_withdraw <= self.__balance:
                self.__balance = self.__balance - amt_withdraw
                print("amount in your balance ", self.__balance)
                print("amount withdraw sucessfull")
            else:
                print("abe graib")
        else:
            print("sale chor")
        self.menu()

# class ke sare data aur function ko sirf ****, object hi call kar sakta hai
        # us class ke function eakdusre ko call nahi kar sakte hai
        # and to overcome this , self
        # self.menu()

# %%
obj  = Atm()
obj.__balance = "hiii" # new attribte will be created not effect the logic....

# private vales can be changed from the out side
# but  its name is changed in memeory
# written like this  _Atm__balance

# in python is nothing truely private => python is a programming language made for adults (gentleman language)
# aap chupa pa raho 

# alwys variables must be public

# obj.create_pin()
# obj._Atm__balance = "pat gaya code"
# Out:
# self address : 2140439449120

# %%
# geter setter 
print(obj.get_balance())

obj.set_balance("satyam")
# Out:
# 0
# Beta bouhat mare ge

# %% [markdown]
# COLLECTION OF OBJECTS

# %%
class Person :
    def __init__(self, name , gender):
        self.name = name
        self.gender = gender

p1 = Person("satyam", "male")
p2 = Person("rolli", "female")
p3 = Person("Ankita", "female")

l = [p1,p2,p3]

for i in l:
    print(i.name)
# Out:
# satyam
# rolli
# Ankita

# %%
# dectionry

d = {'p1':p1 , 'p2':p2 ,'p3':p3}

for i in d:
    print(d[i].name)
    print(d[i],)
# Out:
# satyam
# ...
# rolli
# ...
# Ankita
# ...

# %% [markdown]
# Need of static vaiables

# %%
class Atm:

    # static variables declared outside the class
    __counter = 1

    def __init__(self):
        self.pin = ''
        self.__balance = 0
        # written hrere (STATIC)
        self.cid = Atm.__counter
        Atm.__counter += 1
        # for every costumer new object will be created no counter can be creatd here beacuse they are (instance variable) variable of object => and to overcome these , (ststic variable )=> variable of a class same for all objects


    @staticmethod # static decorator 
    # these types are utuilty fubction
    def get_counter():
        # u can actually without self
        return Atm.__counter
        
    def get_balance(self):
        return self.__balance
    
    def set_balance(self, num):
        if(type(num)== int):
            self.__balance = num
        else:
            print('Beta bouhat mare ge')

    def create_pin(self):
        user_pin = input('enter your pin :' )
        self.pin = user_pin

        user_balance = int(input("Enter Balance :"))
        self.__balance = user_balance

        print("PIN  created sucessfully")
        self.menu()

# %%
c1 = Atm()

# %%
c1.cid
# Out:
# 1

# %%
c2 = Atm()

# %%
c2.cid
# Out:
# 2

# %%
c3 = Atm()

# %%
c3.cid
# problem solved
# Out:
# 3

# %%
Atm.get_counter()
# Out:
# 4

# %%
# methods are also of 2 types => object , self
