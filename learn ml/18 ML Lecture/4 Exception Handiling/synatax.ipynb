# %% [markdown]
# # Syntax error

# %%
# # types of ERROR in program
# - During Compilation => Syntax Error
# - During Execution => Exception

# %%
# index error
# element not in list

l =[1,2,3,4,4,5]
l[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 5
#       1 # index error
#       2 # element not in list
#       4 l =[1,2,3,4,4,5]
# ----> 5 l[100]
#
# IndexError: list index out of range

# %%
# module not found

# %%
# key error => dictionary , key not in dict

d ={'hii':'bye'}

d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       1 # key error => dictionary , key not in dict
#       3 d ={'hii':'bye'}
# ----> 5 d['age']
#
# KeyError: 'age'

# %%
# value error 

int('a')
# invalid input
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # value error
# ----> 3 int('a')
#       4 # invalid input
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# type error

1 + 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # type error
# ----> 3 1 + 'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# name error

print(k)
# variable not in program
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # name error
# ----> 3 print(k)
#       4 # variable not in program
#
# NameError: name 'k' is not defined

# %%
# Attribute error

l = [1,2,3,4]
l.upper()

# us class ka function nahi hai, phir bhe use karte hai
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 # Attribute error
#       3 l = [1,2,3,4]
# ----> 4 l.upper()
#       6 # us class ka function nahi hai, phir bhe use karte hai
#
# AttributeError: 'list' object has no attribute 'upper'
